# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Untitled.csv')

# %%
df
# Out:
#    Unnamed: 0  gender   math reading  writing
# 0           0  female   45.0      65     78.0
# 1           1  female   12.0      78     65.0
# 2           2    male   35.0     NaN     45.0
# 3           3    male  455.0     Nan     23.0
# 4           4  female   45.0      12      NaN
# 5           5  female    NaN      78     12.0
# 6           6    male  789.0      32     65.0
# 7           7    male    NaN      45      NaN
# 8           8  female   12.0      12     21.0
# 9           9    male   45.0      47     78.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# gender        0
# math          2
# reading       1
# writing       2
# dtype: int64

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#    Unnamed: 0  gender   math reading  writing
# 0           0  female   45.0      65     78.0
# 1           1  female   12.0      78     65.0
# 3           3    male  455.0     Nan     23.0
# 6           6    male  789.0      32     65.0
# 8           8  female   12.0      12     21.0
# 9           9    male   45.0      47     78.0

# %%
math_score_mean = df['math'].mean()
df['math'] = df['math'].fillna(math_score_mean)
df
# Out:
#    Unnamed: 0  gender    math reading  writing
# 0           0  female   45.00      65     78.0
# 1           1  female   12.00      78     65.0
# 2           2    male   35.00     NaN     45.0
# 3           3    male  455.00     Nan     23.0
# 4           4  female   45.00      12      NaN
# 5           5  female  179.75      78     12.0
# 6           6    male  789.00      32     65.0
# 7           7    male  179.75      45      NaN
# 8           8  female   12.00      12     21.0
# 9           9    male   45.00      47     78.0

# %%
df.boxplot()
# Out:
# <Axes: >
